# %%
import os
import pandas as pd

# %%
results = pd.read_json(os.path.join('data','ergast-results.json'))

# %%
all_drivers = results['name'].drop_duplicates().to_list()

# %%
races_in_season = results.groupby('year')['raceId'].nunique()
races_in_season
# Out:
# year
# 1950.0     7
# 1951.0     8
# 1952.0     8
# 1953.0     9
# 1954.0     9
#           ..
# 2020.0    17
# 2021.0    22
# 2022.0    22
# 2023.0    22
# 2024.0    24
# Name: raceId, Length: 75, dtype: int64

# %%
def most_of_the_season(row):

# %%
results.groupby(['year','name'])['points'].sum()
# Out:
# year    name
# 1950.0  Alberto Ascari      11.0
#         Alfredo Pián         0.0
#         Bayliss Levrett      0.0
#         Bill Cantrell        0.0
#         Bill Holland         6.0
#                            ...
# 2024.0  Oscar Piastri      167.0
#         Pierre Gasly         8.0
#         Sergio Pérez       126.0
#         Valtteri Bottas      0.0
#         Yuki Tsunoda        21.0
# Name: points, Length: 3208, dtype: float64

# %%
results
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 0        7580.0     2.0       1.0            1.0     1.0  12.0       7.0
# 1        7599.0     3.0       1.0            1.0     1.0   9.0       6.0
# 2        7598.0     3.0       5.0            1.0     2.0  12.0       5.0
# 3        7617.0     4.0       1.0            1.0     1.0   5.0       4.0
# 4        7625.0     4.0       5.0            1.0     2.0  11.0      12.0
# ...         ...     ...       ...            ...     ...   ...       ...
# 26586       NaN  1140.0       NaN            NaN     NaN   NaN       NaN
# 26587       NaN  1141.0       NaN            NaN     NaN   NaN       NaN
# 26588       NaN  1142.0       NaN            NaN     NaN   NaN       NaN
# 26589       NaN  1143.0       NaN            NaN     NaN   NaN       NaN
# 26590       NaN  1144.0       NaN            NaN     NaN   NaN       NaN
#
#       positionText  positionOrder  points  ...               quali_date  \
# ...
