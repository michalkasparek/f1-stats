# %%
# %run prepareStats.py
# Out:
# Last GP in the database: the 2023 Miami Grand Prix

# %%
pd.set_option('display.max_rows', results.shape[0]+1)

pd.set_option('display.max_columns', results.shape[0]+1)

# %%
# results = results[results.year < 2022]

# %% [markdown]
# ## Individual drivers achieving a win, podium or top 6 finish in a given season

# %%
winningDrivers = wins.groupby(["year"]).nunique()["name"].transpose()

# %%
winningDrivers.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
podiumDrivers = podiums.groupby(["year"]).nunique()["name"].transpose()

# %%
podiumDrivers.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
top6drivers = top6.groupby(["year"]).nunique()["name"].transpose()

# %%
top6drivers.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ## Different constructors achieving a win or a podium in a given season

# %%
winningConstructors = wins.groupby(["year"]).nunique()["constructor"].transpose()

# %%
winningConstructors.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
podiumConstructors = podiums.groupby(["year"]).nunique()["constructor"].transpose()

# %%
podiumConstructors.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# ## Drivers' countries and continents of origin

# %%
driverNationalities = results.groupby(["year"]).nunique()["nationality"].transpose()

# %%
driverNationalities.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
winNationality = wins.groupby(["year"]).nunique()["nationality"].transpose()

# %%
winNationality.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
driverContinents = results.groupby(["year"]).nunique()["driverContinent"].transpose()

# %%
driverContinents.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
driverPodiumContinents = podiums.groupby(["year"]).nunique()["driverContinent"].transpose()

# %%
driverPodiumContinents.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# 2019 Formula One World Championship? More like 2019 Formula One European Championship!

# %%
driverWinsContinents = wins.groupby(["year"]).nunique()["driverContinent"].transpose()

# %%
driverWinsContinents.plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# However, 2019 wasn't the first season with only European drivers winning.

# %%
europeanWinsRatio = wins[wins["driverContinent"] == "Europe"].groupby(["year"]).nunique()["raceId"].transpose() / wins.groupby(["year"]).nunique()["raceId"].transpose()

# %%
europeanWinsRatio.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
europeanPodiumRatio = podiums[podiums["driverContinent"] == "Europe"].groupby(["year"])["raceId"].count() / podiums.groupby(["year"])["raceId"].count()

# %%
europeanPodiumRatio.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
results[~results.status.isin(dnqs)].groupby(["year", "location", "round"])["nationality"].nunique().nlargest(10)
# Out:
# year  location        round
# 1974  Anderstorp      7        16
# 1978  Kent            10       16
#       New York State  15       16
#       Spielberg       12       16
# 1979  Dijon           8        16
#       Hockenheim      10       16
#       Montreal        14       16
#       Silverstone     9        16
#       Spielberg       11       16
#       Zandvoort       12       16
# Name: nationality, dtype: int64

# %%
results[(~results.status.isin(dnqs))].groupby(["nationality", "location", "year", "round"])["nationality"].count().nlargest(100)
# Out:
# nationality  location              year  round
# American     Indianapolis          1954  2        55
#                                    1953  2        47
#                                    1950  3        35
#                                    1955  3        35
#                                    1951  2        34
#                                    1956  3        34
#                                    1957  3        33
#                                    1958  4        33
#                                    1959  2        33
#                                    1960  3        33
#                                    1952  2        32
# British      Silverstone           1952  5        18
#                                    1954  5        18
#              Liverpool             1961  5        16
#                                    1959  5        15
#                                    1957  5        14
#              Silverstone           1953  6        14
#                                    1956  6        14
#              Monza                 1961  7        13
#              Nürburg               1961  6        13
#              Liverpool             1955  6        12
#              Nürburg               1958  8        12
#              Silverstone           1958  7        12
#                                    1960  7        12
# Italian      Budapest              1990  10       12
#              Silverstone           1990  8        12
# British      California            1960  10       11
#              Kent                  1964  5        11
#                                    1966  4        11
#              Liverpool             1962  5        11
#              Nürburg               1957  6        11
#              Reims                 1961  4        11
#              Rouen                 1962  4        11
#              Silverstone           1950  1        11
#              Spa                   1961  3        11
# German       Nürburg               1953  7        11
# Italian      Buenos Aires          1955  1        11
#              Monza                 1950  7        11
#              Spa                   1990  11       11
# British      Casablanca            1958  11       10
#              Monza                 1959  8        10
#              Nürburg               1966  6        10
#                                    1967  7        10
#              Silverstone           1963  5        10
#                                    1965  5        10
#                                    1967  6        10
#              Spa                   1962  3        10
# German       Nürburg               1952  6        10
# Italian      Adelaide              1989  16       10
#                                    1991  16       10
#              Budapest              1989  10       10
#              Estoril               1990  13       10
#              Imola                 1988  2        10
#              Jerez de la Frontera  1989  14       10
#                                    1990  14       10
#              Le Castellet          1988  7        10
#                                    1990  7        10
#              Monte-Carlo           1988  3        10
#                                    1990  4        10
#              Montmeló              1991  14       10
#              Montreal              1989  6        10
#                                    1990  5        10
#              Monza                 1961  7        10
#                                    1989  12       10
#                                    1990  12       10
#              Suzuka                1990  15       10
#              São Paulo             1990  2        10
# American     Mexico City           1963  9         9
# British      Monte-Carlo           1957  2         9
#              Nürburg               1962  6         9
#              Reims                 1958  6         9
#                                    1960  6         9
#              Silverstone           1951  5         9
#                                    1973  9         9
#              Zandvoort             1958  3         9
#                                    1960  4         9
#                                    1966  5         9
# French       Reims                 1950  6         9
#                                    1951  4         9
# Italian      Adelaide              1988  16        9
#                                    1990  16        9
#              Budapest              1988  10        9
#              Detroit               1988  6         9
#              Estoril               1988  13        9
#                                    1989  13        9
#              Hockenheim            1988  9         9
#                                    1989  9         9
#                                    1990  9         9
#              Imola                 1987  2         9
#                                    1989  2         9
#                                    1990  3         9
#              Jerez de la Frontera  1988  14        9
#              Mexico City           1988  4         9
#                                    1989  4         9
#                                    1990  6         9
#              Monte-Carlo           1989  3         9
#                                    1991  4         9
#              Monza                 1988  12        9
#              Phoenix               1989  5         9
#                                    1990  1         9
# Name: nationality, dtype: int64

# %% [markdown]
# ## European Championship

# %% [markdown]
# Counting only points achieved by European drivers on European circuits (including Istanbul, Baku and Sochi).
#
# Michael Schumacher would have won the 1997 EC, but we're going to DSQ him for hitting Jacques Villeneuve in Jerez, just like in the real 1997 WC.
#
# See also: [European Championship](https://f1.fandom.com/wiki/European_Championship)
#
# > The European Championship existed as a predecessor to the Formula One World Championship and was held between 1931 and 1939. The first champion was Ferdinando Minoia, with Rudolf Caracciola winning three titles. The championship was discontinued because of the outbreak of World War II in 1939, and no champion was officially declared for the last season. From 1936, the German drivers, including Caracciola, drove under the Nazi flag.

# %%
ec = results[~(results.name.eq("Michael Schumacher") & results.year.eq(1997))]
ec = ec[ec.nationality.isin(Europe) & ec.country.isin(Europe)]

# %%
ec.groupby(["year", "name"]).agg({"points": sum}).groupby("year")["points"].nlargest(3)
# Out:
# year  year  name
# 1950  1950  Nino Farina               30.00
#             Luigi Fagioli             28.00
#             Louis Rosier              13.00
# 1951  1951  Alberto Ascari            28.00
#             Nino Farina               22.00
#             Luigi Villoresi           18.00
# 1952  1952  Alberto Ascari            53.50
#             Nino Farina               27.00
#             Piero Taruffi             22.00
# 1953  1953  Alberto Ascari            37.50
#             Nino Farina               32.00
#             Mike Hawthorn             24.00
# 1954  1954  Mike Hawthorn             24.64
#             Maurice Trintignant       14.00
#             Karl Kling                12.00
# 1955  1955  Stirling Moss             22.00
#             Eugenio Castellotti       12.00
#             Piero Taruffi              9.00
# 1956  1956  Stirling Moss             28.00
#             Peter Collins             25.00
#             Jean Behra                16.00
# 1957  1957  Stirling Moss             24.00
#             Luigi Musso               16.00
#             Mike Hawthorn             13.00
# 1958  1958  Mike Hawthorn             39.00
#             Stirling Moss             24.00
#             Tony Brooks               24.00
# 1959  1959  Stirling Moss             25.50
#             Tony Brooks               23.00
#             Maurice Trintignant       12.00
# 1960  1960  Innes Ireland             11.00
#             Stirling Moss             11.00
#             Olivier Gendebien         10.00
# 1961  1961  Wolfgang von Trips        33.00
#             Stirling Moss             21.00
#             Jim Clark                 11.00
# 1962  1962  Graham Hill               37.00
#             Jim Clark                 21.00
#             John Surtees              19.00
# 1963  1963  Jim Clark                 51.00
#             John Surtees              22.00
#             Graham Hill               13.00
# 1964  1964  Graham Hill               32.00
#             Jim Clark                 30.00
#             John Surtees              28.00
# 1965  1965  Jim Clark                 45.00
#             Graham Hill               34.00
#             Jackie Stewart            33.00
# 1966  1966  Jochen Rindt              18.00
#             Graham Hill               17.00
#             John Surtees              15.00
# 1967  1967  Jim Clark                 23.00
#             John Surtees              13.00
#             Jackie Stewart            10.00
# 1968  1968  Jacky Ickx                27.00
#             Jackie Stewart            26.00
#             Graham Hill               24.00
# 1969  1969  Jackie Stewart            51.00
#             Jacky Ickx                22.00
#             Jean-Pierre Beltoise      15.00
# 1970  1970  Jochen Rindt              45.00
#             Clay Regazzoni            21.00
#             Jackie Stewart            21.00
# 1971  1971  Jackie Stewart            45.00
#             Ronnie Peterson           23.00
#             Jacky Ickx                19.00
# 1972  1972  Jacky Ickx                21.00
#             Jackie Stewart            18.00
#             Mike Hailwood             13.00
# 1973  1973  Jackie Stewart            50.00
#             Ronnie Peterson           43.00
#             François Cevert           41.00
# 1974  1974  Clay Regazzoni            36.00
#             Niki Lauda                32.00
#             Ronnie Peterson           30.00
# 1975  1975  Niki Lauda                50.50
#             James Hunt                23.00
#             Clay Regazzoni            19.00
# 1976  1976  James Hunt                41.00
#             Niki Lauda                40.00
#             Clay Regazzoni            19.00
# 1977  1977  Niki Lauda                50.00
#             Jochen Mass               19.00
#             Gunnar Nilsson            18.00
# 1978  1978  Ronnie Peterson           37.00
#             Niki Lauda                34.00
#             John Watson               21.00
# 1979  1979  Clay Regazzoni            28.00
#             Jacques Laffite           18.00
#             Patrick Depailler         11.00
# 1980  1980  Jacques Laffite           26.00
#             Didier Pironi             16.00
#             René Arnoux               11.00
# 1981  1981  Alain Prost               33.00
#             Jacques Laffite           33.00
#             John Watson               21.00
# 1982  1982  Didier Pironi             34.00
#             Keke Rosberg              31.00
#             Patrick Tambay            25.00
# 1983  1983  Alain Prost               55.00
#             René Arnoux               36.00
#             Patrick Tambay            34.00
# 1984  1984  Niki Lauda                57.00
#             Alain Prost               49.50
#             Michele Alboreto          30.50
# 1985  1985  Alain Prost               59.00
#             Michele Alboreto          34.00
#             Elio de Angelis           25.00
# 1986  1986  Nigel Mansell             59.00
#             Alain Prost               49.00
#             Keke Rosberg              19.00
# 1987  1987  Nigel Mansell             49.00
#             Alain Prost               33.00
#             Stefan Johansson          22.00
# 1988  1988  Alain Prost               60.00
#             Gerhard Berger            28.00
#             Michele Alboreto          19.00
# 1989  1989  Alain Prost               64.00
#             Nigel Mansell             29.00
#             Gerhard Berger            21.00
# 1990  1990  Alain Prost               49.00
#             Gerhard Berger            27.00
#             Thierry Boutsen           22.00
# 1991  1991  Nigel Mansell             62.00
#             Riccardo Patrese          28.00
#             Gerhard Berger            27.00
# 1992  1992  Nigel Mansell             78.00
#             Martin Brundle            30.00
#             Michael Schumacher        30.00
# 1993  1993  Alain Prost               67.00
#             Damon Hill                52.00
#             Michael Schumacher        42.00
# 1994  1994  Damon Hill                69.00
#             Michael Schumacher        56.00
#             Gerhard Berger            26.00
# 1995  1995  Michael Schumacher        66.00
#             Damon Hill                45.00
#             David Coulthard           37.00
# 1996  1996  Michael Schumacher        49.00
#             Damon Hill                47.00
#             Jean Alesi                33.00
# 1997  1997  Heinz-Harald Frentzen     33.00
#             Jean Alesi                27.00
#             David Coulthard           26.00
# 1998  1998  Mika Häkkinen             64.00
#             Michael Schumacher        62.00
#             David Coulthard           39.00
# 1999  1999  David Coulthard           48.00
#             Eddie Irvine              44.00
#             Mika Häkkinen             42.00
# 2000  2000  Mika Häkkinen             77.00
#             David Coulthard           61.00
#             Michael Schumacher        48.00
# 2001  2001  Michael Schumacher        75.00
#             David Coulthard           37.00
#             Ralf Schumacher           36.00
# 2002  2002  Michael Schumacher        94.00
#             David Coulthard           27.00
#             Ralf Schumacher           26.00
# 2003  2003  Michael Schumacher        64.00
#             Kimi Räikkönen            48.00
#             Ralf Schumacher           42.00
# 2004  2004  Michael Schumacher        86.00
#             Jenson Button             50.00
#             Fernando Alonso           34.00
# 2005  2005  Fernando Alonso           85.00
#             Kimi Räikkönen            69.00
#             Michael Schumacher        35.00
# 2006  2006  Michael Schumacher        77.00
#             Fernando Alonso           66.00
#             Kimi Räikkönen            37.00
# 2007  2007  Fernando Alonso           63.00
#             Lewis Hamilton            55.00
#             Kimi Räikkönen            53.00
# 2008  2008  Lewis Hamilton            64.00
#             Robert Kubica             40.00
#             Kimi Räikkönen            38.00
# 2009  2009  Jenson Button             49.00
#             Kimi Räikkönen            37.00
#             Sebastian Vettel          36.00
# 2010  2010  Lewis Hamilton           108.00
#             Sebastian Vettel         106.00
#             Fernando Alonso          102.00
# 2011  2011  Sebastian Vettel         198.00
#             Fernando Alonso          146.00
#             Lewis Hamilton           111.00
# 2012  2012  Fernando Alonso          126.00
#             Kimi Räikkönen           103.00
#             Sebastian Vettel          75.00
# 2013  2013  Sebastian Vettel         120.00
#             Fernando Alonso          104.00
#             Nico Rosberg              80.00
# 2014  2014  Lewis Hamilton           166.00
#             Nico Rosberg             159.00
#             Valtteri Bottas          107.00
# 2015  2015  Lewis Hamilton           159.00
#             Sebastian Vettel         121.00
#             Nico Rosberg             115.00
# 2016  2016  Lewis Hamilton           186.00
#             Nico Rosberg             163.00
#             Kimi Räikkönen           100.00
# 2017  2017  Sebastian Vettel         155.00
#             Lewis Hamilton           152.00
#             Valtteri Bottas          141.00
# 2018  2018  Lewis Hamilton           226.00
#             Sebastian Vettel         162.00
#             Kimi Räikkönen           138.00
# 2019  2019  Lewis Hamilton           217.00
#             Valtteri Bottas          164.00
#             Max Verstappen           148.00
# 2020  2020  Lewis Hamilton           307.00
#             Valtteri Bottas          197.00
#             Max Verstappen           170.00
# 2021  2021  Max Verstappen           239.50
#             Lewis Hamilton           229.50
#             Valtteri Bottas          157.00
# 2022  2022  Max Verstappen           243.00
#             George Russell           139.00
#             Lewis Hamilton           116.00
# 2023  2023  Max Verstappen            18.00
#             Charles Leclerc           15.00
#             Fernando Alonso           12.00
# Name: points, dtype: float64

# %%
ec.groupby(["year", "name"]).agg({"points": sum}).groupby("year")["points"].nlargest(1).groupby("name").count().nlargest(50)
# Out:
# name
# Lewis Hamilton           8
# Alain Prost              7
# Michael Schumacher       7
# Stirling Moss            4
# Nigel Mansell            4
# Sebastian Vettel         3
# Max Verstappen           3
# Jim Clark                3
# Alberto Ascari           3
# Jackie Stewart           3
# Niki Lauda               3
# Fernando Alonso          3
# Mika Häkkinen            2
# Mike Hawthorn            2
# Graham Hill              2
# Jochen Rindt             2
# Clay Regazzoni           2
# Jacky Ickx               2
# Nino Farina              1
# Ronnie Peterson          1
# Jenson Button            1
# James Hunt               1
# Jacques Laffite          1
# Innes Ireland            1
# Heinz-Harald Frentzen    1
# Didier Pironi            1
# David Coulthard          1
# Damon Hill               1
# Wolfgang von Trips       1
# Name: points, dtype: int64

# %% [markdown]
# In fact, Stirling Moss would have been a 5-time European F1 Champion, as he achieved better results than Innes Ireland in 1960.

# %% [markdown]
# ## Drivers' age

# %%
results["ageyears"] = results["age"] / np.timedelta64(1, 'Y')

# %%
meanAgeSeason = results.groupby("year")["ageyears"].mean()
maxAgeSeason = results.groupby("year")["ageyears"].max()
minAgeSeason = results.groupby("year")["ageyears"].min()

# %%
fig, ax = plt.subplots()
ax.plot(meanAgeSeason)
ax.plot(maxAgeSeason)
ax.plot(minAgeSeason)
plt.title("Age of the youngest driver, median age, age of the oldest driver")
plt.show()

# %% [markdown]
# ## How diverse has the F1 calendar been?

# %%
results.loc[results.country.isin(Europe),"locationContinent"]="Europe"
results.loc[results.country.isin(NAmerica),"locationContinent"]="NAmerica"
results.loc[results.country.isin(SAmerica),"locationContinent"]="SAmerica"
results.loc[results.country.isin(Asia),"locationContinent"]="Asia"
results.loc[results.country.isin(Africa),"locationContinent"]="Africa"
results.loc[results.country.isin(Oceania),"locationContinent"]="Oceania"

# %%
results.groupby("year")["country"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
results.groupby("year")["locationContinent"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
results[results["locationContinent"] == "Europe"].groupby("year")["round"].nunique().plot.bar()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
europeanRacesRatio = pd.Series(results[results["locationContinent"] == "Europe"].groupby("year")["round"].nunique() / results.groupby("year")["round"].nunique())
NAmericanRacesRatio = pd.Series(results[results["locationContinent"] == "NAmerica"].groupby("year")["round"].nunique() / results.groupby("year")["round"].nunique())
SAmericanRacesRatio = pd.Series(results[results["locationContinent"] == "SAmerica"].groupby("year")["round"].nunique() / results.groupby("year")["round"].nunique())
asianRacesRatio = pd.Series(results[results["locationContinent"] == "Asia"].groupby("year")["round"].nunique() / results.groupby("year")["round"].nunique())
africanRacesRatio = pd.Series(results[results["locationContinent"] == "Africa"].groupby("year")["round"].nunique() / results.groupby("year")["round"].nunique())
oceanianRacesRatio = pd.Series(results[results["locationContinent"] == "Oceania"].groupby("year")["round"].nunique() / results.groupby("year")["round"].nunique())

# %%
plt.plot(europeanRacesRatio, label="Europe (including Russia, Turkey and Azerbaijan)")
plt.plot(asianRacesRatio, label="Asia")
plt.plot(NAmericanRacesRatio, label="North America")
plt.plot(SAmericanRacesRatio, label="South America")
plt.plot(africanRacesRatio, label="Africa")
plt.plot(oceanianRacesRatio, label="Australia and Oceania")
plt.legend()
plt.show()

# %%
westernEurope = ["Austria", "Belgium", "Germany", "France", "Italy", "Monaco", "Netherlands", "Portugal", "Spain", "Sweden", "Switzerland", "UK"]
results["westernEurope"] = False
results.loc[results.country.isin(westernEurope),"westernEurope"] = True

# %%
results[results["westernEurope"] == True].groupby("year")["round"].nunique().plot()
# Out:
# <AxesSubplot:xlabel='year'>
